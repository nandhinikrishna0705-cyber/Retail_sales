# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine("mysql+pymysql://root:root@localhost:3306/final")

# %%
 df= pd.read_sql("select * from orders",engine)

# %%
df
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  01-01-2016    03-01-2016
# 1            2         1212             4  01-01-2016    04-01-2016
# 2            3          523             4  02-01-2016    05-01-2016
# 3            4          175             4  03-01-2016    04-01-2016
# 4            5         1324             4  03-01-2016    06-01-2016
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  06-09-2018    06-09-2018
# 1611      1612            3             3  21-10-2018    21-10-2018
# 1612      1613            1             3  18-11-2018    18-11-2018
# 1613      1614          135             3  28-11-2018    28-11-2018
# 1614      1615          136             3  28-12-2018    28-12-2018
#
#      shipped_date  store_id  staff_id
# 0      03-01-2016         1         2
# 1      03-01-2016         2         6
# ...

# %%
df2 = pd.read_sql("select * from order_items",engine)

# %%
df2
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount  \
# 0            1        1          20         1      599.99      0.20
# 1            1        2           8         2     1799.99      0.07
# 2            1        3          10         2     1549.00      0.05
# 3            1        4          16         2      599.99      0.05
# 4            1        5           4         1     2899.99      0.20
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2     2299.99      0.07
# 4718      1614        3         213         2      269.99      0.20
# 4719      1615        1         197         2     2299.99      0.20
# 4720      1615        2         214         1      899.99      0.07
# 4721      1615        3         182         1     2499.99      0.20
#
#       total_price                                    product_name
# 0          599.79  Electra Townie Original 7D EQ - Women's - 2016
# ...

# %%
df3 = pd.read_sql("select * from customers",engine)

# %%
df3
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2       Kasha      Todd            None
# 2               3      Tameka    Fisher            None
# 3               4       Daryl    Spence            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison            None
# 1441         1442      Cassie     Cline            None
# 1442         1443      Lezlie      Lamb            None
# 1443         1444      Ivette     Estes            None
# 1444         1445       Ester   Acevedo            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
df.describe()
# Out:
#           order_id  customer_id  order_status     store_id     staff_id
# count  1615.000000  1615.000000   1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517      3.778947     1.892260     5.855108
# std     466.354658   443.229967      0.693430     0.558395     1.913899
# min       1.000000     1.000000      1.000000     1.000000     2.000000
# 25%     404.500000   237.000000      4.000000     2.000000     6.000000
# 50%     808.000000   638.000000      4.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000      4.000000     2.000000     7.000000
# max    1615.000000  1445.000000      4.000000     3.000000     9.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      4722 non-null   int64
#  1   item_id       4722 non-null   int64
#  2   product_id    4722 non-null   int64
#  3   quantity      4722 non-null   int64
#  4   list_price    4722 non-null   float64
#  5   discount      4722 non-null   float64
#  6   total_price   4722 non-null   float64
#  7   product_name  4722 non-null   object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 295.3+ KB

# %%
df3.value_counts()
# Out:
# customer_id  first_name  last_name  phone           email                       street                   city            state  zip_code
# 5            Charolette  Rice       (916) 381-6003  charolette.rice@msn.com     107 River Dr.            Sacramento      CA     95820       1
# 7            Latasha     Hays       (716) 986-3359  latasha.hays@hotmail.com    7014 Manor Station Rd.   Buffalo         NY     14215       1
# 12           Robby       Sykes      (516) 583-7761  robby.sykes@hotmail.com     486 Rock Maple Street    Hempstead       NY     11550       1
# 16           Emmitt      Sanchez    (212) 945-8823  emmitt.sanchez@hotmail.com  461 Squaw Creek Road     New York        NY     10002       1
# 26           Theo        Reese      (562) 215-2907  theo.reese@gmail.com        8755 W. Wild Horse St.   Long Beach      NY     11561       1
# ...

# %%
import pandas as pd

# %%
merged = pd.merge(df,df2,on='order_id')

# %%
merged
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  01-01-2016    03-01-2016
# 1            1          259             4  01-01-2016    03-01-2016
# 2            1          259             4  01-01-2016    03-01-2016
# 3            1          259             4  01-01-2016    03-01-2016
# 4            1          259             4  01-01-2016    03-01-2016
# ...        ...          ...           ...         ...           ...
# 4717      1614          135             3  28-11-2018    28-11-2018
# 4718      1614          135             3  28-11-2018    28-11-2018
# 4719      1615          136             3  28-12-2018    28-12-2018
# 4720      1615          136             3  28-12-2018    28-12-2018
# 4721      1615          136             3  28-12-2018    28-12-2018
#
#      shipped_date  store_id  staff_id  item_id  product_id  quantity  \
# 0      03-01-2016         1         2        1          20         1
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df2['product_id'],df2['total_price'])

# %%
orders=df.groupby('customer_id')['order_date'].count().reset_index()

# %%
orders
# Out:
#       customer_id  order_date
# 0               1           3
# 1               2           3
# 2               3           3
# 3               4           3
# 4               5           3
# ...           ...         ...
# 1440         1441           1
# 1441         1442           1
# 1442         1443           1
# 1443         1444           1
# 1444         1445           1
#
# [1445 rows x 2 columns]

# %%
recency=orders.groupby('order_date')['customer_id'].count().reset_index()

# %%
recency
# Out:
#    order_date  customer_id
# 0           1         1314
# 1           2           92
# 2           3           39

# %%
recency=recency.rename(columns={'order_date':'recency'})

# %%
recency
# Out:
#    recency  customer_id
# 0        1         1314
# 1        2           92
# 2        3           39

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(recency['customer_id'],labels=recency['recency'])
plt.title("total customer by order count")
# Out:
# Text(0.5, 1.0, 'total customer by order count')

# %%
df1=df.groupby('customer_id')['order_id'].count().reset_index()

# %%
df1
# Out:
#       customer_id  order_id
# 0               1         3
# 1               2         3
# 2               3         3
# 3               4         3
# 4               5         3
# ...           ...       ...
# 1440         1441         1
# 1441         1442         1
# 1442         1443         1
# 1443         1444         1
# 1444         1445         1
#
# [1445 rows x 2 columns]

# %%
df1=df1.rename(columns={'order_id':'frequency'})

# %%
df1
# Out:
#       customer_id  frequency
# 0               1          3
# 1               2          3
# 2               3          3
# 3               4          3
# 4               5          3
# ...           ...        ...
# 1440         1441          1
# 1441         1442          1
# 1442         1443          1
# 1443         1444          1
# 1444         1445          1
#
# [1445 rows x 2 columns]

# %%
frequency=df1.groupby('frequency')['customer_id'].count().reset_index()

# %%
frequency
# Out:
#    frequency  customer_id
# 0          1         1314
# 1          2           92
# 2          3           39

# %%
plt.bar(frequency['frequency'],frequency['customer_id'])
plt.title("order id count by customers")
# Out:
# Text(0.5, 1.0, 'order id count by customers')

# %%
df2=merged.groupby('customer_id')['total_price'].sum().reset_index()

# %%
df2
# Out:
#       customer_id  total_price
# 0               1     30644.78
# 1               2     21652.87
# 2               3     26248.66
# 3               4     24197.81
# 4               5     19442.01
# ...           ...          ...
# 1440         1441     10497.61
# 1441         1442      7841.32
# 1442         1443     11237.59
# 1443         1444      1749.57
# 1444         1445      9999.78
#
# [1445 rows x 2 columns]

# %%
monetary=df2.rename(columns={'total_price':'monetary'})

# %%
monetary
# Out:
#       customer_id  monetary
# 0               1  30644.78
# 1               2  21652.87
# 2               3  26248.66
# 3               4  24197.81
# 4               5  19442.01
# ...           ...       ...
# 1440         1441  10497.61
# 1441         1442   7841.32
# 1442         1443  11237.59
# 1443         1444   1749.57
# 1444         1445   9999.78
#
# [1445 rows x 2 columns]

# %%
mon=monetary.head(5)

# %%
mon
# Out:
#    customer_id  monetary
# 0            1  30644.78
# 1            2  21652.87
# 2            3  26248.66
# 3            4  24197.81
# 4            5  19442.01

# %%
plt.bar(mon['customer_id'],mon['monetary'])
plt.title("top 5 customers total price")
plt.xlabel("customer")
plt.ylabel("total price")
# Out:
# Text(0, 0.5, 'total price')

# %%
recency
# Out:
#    recency  customer_id
# 0        1         1314
# 1        2           92
# 2        3           39

# %%
recency.dtypes
# Out:
# recency        int64
# customer_id    int64
# dtype: object

# %%
frequency.dtypes
# Out:
# frequency      int64
# customer_id    int64
# dtype: object

# %%
monetary
# Out:
#       customer_id  monetary
# 0               1  30644.78
# 1               2  21652.87
# 2               3  26248.66
# 3               4  24197.81
# 4               5  19442.01
# ...           ...       ...
# 1440         1441  10497.61
# 1441         1442   7841.32
# 1442         1443  11237.59
# 1443         1444   1749.57
# 1444         1445   9999.78
#
# [1445 rows x 2 columns]

# %%
monetary.dtypes
# Out:
# customer_id      int64
# monetary       float64
# dtype: object

# %%
merge= recency.merge(frequency,on='customer_id').merge(monetary,on='customer_id')

# %%
merge
# Out:
#    recency  customer_id  frequency  monetary
# 0        1         1314          1   7767.48
# 1        2           92          2   3278.48
# 2        3           39          3  19143.44

# %%
merge= merge[['customer_id','recency','frequency','monetary']]

# %%
merge
# Out:
#    customer_id  recency  frequency  monetary
# 0         1314        1          1   7767.48
# 1           92        2          2   3278.48
# 2           39        3          3  19143.44

# %%
mr=merge.to_csv("finalproject.csv", index=False)

# %%
merge
# Out:
#    customer_id  recency  frequency  monetary
# 0         1314        1          1   7767.48
# 1           92        2          2   3278.48
# 2           39        3          3  19143.44

# %%
finalproject.to_sql(name="customer_segments", con=engine, if_exists="replace", index=False)

# %%
df1
# Out:
#       customer_id  frequency
# 0               1          3
# 1               2          3
# 2               3          3
# 3               4          3
# 4               5          3
# ...           ...        ...
# 1440         1441          1
# 1441         1442          1
# 1442         1443          1
# 1443         1444          1
# 1444         1445          1
#
# [1445 rows x 2 columns]

# %%
fr=df1.to_csv("frequency.csv", index=False)

# %%
df1.to_sql(name="frequency", con=engine, if_exists="replace", index=False)
# Out:
# 1445
